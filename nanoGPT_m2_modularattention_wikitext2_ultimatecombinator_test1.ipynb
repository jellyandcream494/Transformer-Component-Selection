# %% [markdown]
# <a href="https://colab.research.google.com/github/jellyandcream494/Transformer-Component-Selection/blob/main/nanoGPT_m2_modularattention_wikitext2_ultimatecombinator_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NanoGPT on Mac M2 (End-to-End)
# This notebook pulls all necessary code from `nanoGPT` to run a miniature character-level Shakespeare model directly on a Macbook Air M2.
# We use the configuration overrides requested: `--device=mps --compile=False --eval_iters=20 --log_interval=1 --block_size=64 --batch_size=12 --n_layer=4 --n_head=4 --n_embd=128 --max_iters=2000 --lr_decay_iters=2000 --dropout=0.0`.

# %% [markdown]
# ## Step 2: Prepare the Data
# This cell downloads the WikiText-2 dataset and encodes it into `train.bin` and `val.bin` using subword tokenization (BPE) via OpenAI's `tiktoken`.

# %%
import os
import pickle
import numpy as np
import requests
import tiktoken

# We'll save the data to a local 'data/wikitext2_bpe' directory to keep things organized.
data_dir = os.path.join('data', 'wikitext2_bpe')
os.makedirs(data_dir, exist_ok=True)

input_file_path = os.path.join(data_dir, 'wikitext-2-train.txt')
if not os.path.exists(input_file_path):
    print("Downloading WikiText-2 dataset...")
    data_url = 'https://raw.githubusercontent.com/pytorch/examples/master/word_language_model/data/wikitext-2/train.txt'
    with open(input_file_path, 'w', encoding='utf-8') as f:
        f.write(requests.get(data_url).text)

with open(input_file_path, 'r', encoding='utf-8') as f:
    data = f.read()
print(f"length of dataset in characters: {len(data):,}")

# Use tiktoken for subword tokenization
enc = tiktoken.get_encoding("gpt2")
tokens = enc.encode(data, allowed_special={"<|endoftext|>"})
print(f"Total tokens: {len(tokens):,}")

# Split into train/val (e.g., 90/10)
n = len(tokens)
train_ids = tokens[:int(n*0.9)]
val_ids = tokens[int(n*0.9):]
print(f"train has {len(train_ids):,} tokens")
print(f"val has {len(val_ids):,} tokens")

# Export to bin files
train_ids = np.array(train_ids, dtype=np.uint16)
val_ids = np.array(val_ids, dtype=np.uint16)
train_ids.tofile(os.path.join(data_dir, 'train.bin'))
val_ids.tofile(os.path.join(data_dir, 'val.bin'))

# Save meta.pkl
vocab_size = enc.n_vocab # usually 50257
meta = {'vocab_size': vocab_size}
with open(os.path.join(data_dir, 'meta.pkl'), 'wb') as f:
    pickle.dump(meta, f)
print("Data preparation complete.")
# Out:
# length of dataset in characters: 10,780,437
# Total tokens: 2,448,382
# train has 2,203,543 tokens
# val has 244,839 tokens
# Data preparation complete.

# %% [markdown]
# ## Step 3: Model Architecture
# This contains the full `model.py` logic exactly as is. We include it directly in the notebook as requested so it's fully self-contained.

# %%
"""
Full definition of a GPT Language Model, all of it in this single file.
References:
1) the official GPT-2 TensorFlow implementation released by OpenAI:
https://github.com/openai/gpt-2/blob/master/src/model.py
2) huggingface/transformers PyTorch implementation:
https://github.com/huggingface/transformers/blob/main/src/transformers/models/gpt2/modeling_gpt2.py
"""

import math
import inspect
from dataclasses import dataclass

import torch
import torch.nn as nn
from torch.nn import functional as F

class LayerNorm(nn.Module):
    """ LayerNorm but with an optional bias. PyTorch doesn't support simply bias=False """

    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None

    def forward(self, input):
        return F.layer_norm(input, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        # key, query, value projections for all heads, but in a batch
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        # output projection
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        # regularization
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.dropout = config.dropout
        # flash attention make GPU go brrrrr but support is only in PyTorch >= 2.0
        self.flash = hasattr(torch.nn.functional, 'scaled_dot_product_attention')
        if not self.flash:
            print("WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0")
            # causal mask to ensure that attention is only applied to the left in the input sequence
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                        .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size() # batch size, sequence length, embedding dimensionality (n_embd)

        # calculate query, key, values for all heads in batch and move head forward to be the batch dim
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) # (B, nh, T, hs)

        # causal self-attention; Self-attend: (B, nh, T, hs) x (B, nh, hs, T) -> (B, nh, T, T)
        if self.flash:
            # efficient attention using Flash Attention CUDA kernels
            y = torch.nn.functional.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.dropout if self.training else 0, is_causal=True)
        else:
            # manual implementation of attention
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v # (B, nh, T, T) x (B, nh, T, hs) -> (B, nh, T, hs)
        y = y.transpose(1, 2).contiguous().view(B, T, C) # re-assemble all head outputs side by side

        # output projection
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.c_fc    = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu    = nn.GELU()
        self.c_proj  = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)

    def forward(self, x):
        x = self.c_fc(x)
        x = self.gelu(x)
        x = self.c_proj(x)
        x = self.dropout(x)
        return x

class Block(nn.Module):

    def __init__(self, config):
        super().__init__()
        self.ln_1 = LayerNorm(config.n_embd, bias=config.bias)
        # MODULAR: Instantiate the attention layer passed inside the configuration
        self.attn = config.attention_class(config)
        self.ln_2 = LayerNorm(config.n_embd, bias=config.bias)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln_1(x))
        x = x + self.mlp(self.ln_2(x))
        return x

@dataclass
class GPTConfig:
    block_size: int = 1024
    vocab_size: int = 50304 # GPT-2 vocab_size of 50257, padded up to nearest multiple of 64 for efficiency
    n_layer: int = 12
    n_head: int = 12
    n_embd: int = 768
    dropout: float = 0.0
    bias: bool = True # True: bias in Linears and LayerNorms, like GPT-2. False: a bit better and faster
    # MODULAR: Attach the specific class reference
    attention_class: type = CausalSelfAttention

class GPT(nn.Module):

    def __init__(self, config):
        super().__init__()
        assert config.vocab_size is not None
        assert config.block_size is not None
        self.config = config

        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size, config.n_embd),
            wpe = nn.Embedding(config.block_size, config.n_embd),
            drop = nn.Dropout(config.dropout),
            h = nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f = LayerNorm(config.n_embd, bias=config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        # with weight tying when using torch.compile() some warnings get generated:
        # "UserWarning: functional_call was passed multiple values for tied weights.
        # This behavior is deprecated and will be an error in future versions"
        # not 100% sure what this is, so far seems to be harmless. TODO investigate
        self.transformer.wte.weight = self.lm_head.weight # https://paperswithcode.com/method/weight-tying

        # init all weights
        self.apply(self._init_weights)
        # apply special scaled init to the residual projections, per GPT-2 paper
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                torch.nn.init.normal_(p, mean=0.0, std=0.02/math.sqrt(2 * config.n_layer))

        # report number of parameters
        print("number of parameters: %.2fM" % (self.get_num_params()/1e6,))

    def get_num_params(self, non_embedding=True):
        """
        Return the number of parameters in the model.
        For non-embedding count (default), the position embeddings get subtracted.
        The token embeddings would too, except due to the parameter sharing these
        params are actually used as weights in the final layer, so we include them.
        """
        n_params = sum(p.numel() for p in self.parameters())
        if non_embedding:
            n_params -= self.transformer.wpe.weight.numel()
        return n_params

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size, f"Cannot forward sequence of length {t}, block size is only {self.config.block_size}"
        pos = torch.arange(0, t, dtype=torch.long, device=device) # shape (t)

        # forward the GPT model itself
        tok_emb = self.transformer.wte(idx) # token embeddings of shape (b, t, n_embd)
        pos_emb = self.transformer.wpe(pos) # position embeddings of shape (t, n_embd)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            # if we are given some desired targets also calculate the loss
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
        else:
            # inference-time mini-optimization: only forward the lm_head on the very last position
            logits = self.lm_head(x[:, [-1], :]) # note: using list [-1] to preserve the time dim
            loss = None

        return logits, loss

    def crop_block_size(self, block_size):
        # model surgery to decrease the block size if necessary
        # e.g. we may load the GPT2 pretrained model checkpoint (block size 1024)
        # but want to use a smaller block size for some smaller, simpler model
        assert block_size <= self.config.block_size
        self.config.block_size = block_size
        self.transformer.wpe.weight = nn.Parameter(self.transformer.wpe.weight[:block_size])
        for block in self.transformer.h:
            if hasattr(block.attn, 'bias'):
                block.attn.bias = block.attn.bias[:,:,:block_size,:block_size]

    @classmethod
    def from_pretrained(cls, model_type, override_args=None):
        assert model_type in {'gpt2', 'gpt2-medium', 'gpt2-large', 'gpt2-xl'}
        override_args = override_args or {} # default to empty dict
        # only dropout can be overridden see more notes below
        assert all(k == 'dropout' for k in override_args)
        from transformers import GPT2LMHeadModel
        print("loading weights from pretrained gpt: %s" % model_type)

        # n_layer, n_head and n_embd are determined from model_type
        config_args = {
            'gpt2':         dict(n_layer=12, n_head=12, n_embd=768),  # 124M params
            'gpt2-medium':  dict(n_layer=24, n_head=16, n_embd=1024), # 350M params
            'gpt2-large':   dict(n_layer=36, n_head=20, n_embd=1280), # 774M params
            'gpt2-xl':      dict(n_layer=48, n_head=25, n_embd=1600), # 1558M params
        }[model_type]
        print("forcing vocab_size=50257, block_size=1024, bias=True")
        config_args['vocab_size'] = 50257 # always 50257 for GPT model checkpoints
        config_args['block_size'] = 1024 # always 1024 for GPT model checkpoints
        config_args['bias'] = True # always True for GPT model checkpoints
        # we can override the dropout rate, if desired
        if 'dropout' in override_args:
            print(f"overriding dropout rate to {override_args['dropout']}")
            config_args['dropout'] = override_args['dropout']
        # create a from-scratch initialized minGPT model
        config = GPTConfig(**config_args)
        model = GPT(config)
        sd = model.state_dict()
        sd_keys = sd.keys()
        sd_keys = [k for k in sd_keys if not k.endswith('.attn.bias')] # discard this mask / buffer, not a param

        # init a huggingface/transformers model
        model_hf = GPT2LMHeadModel.from_pretrained(model_type)
        sd_hf = model_hf.state_dict()

        # copy while ensuring all of the parameters are aligned and match in names and shapes
        sd_keys_hf = sd_hf.keys()
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.masked_bias')] # ignore these, just a buffer
        sd_keys_hf = [k for k in sd_keys_hf if not k.endswith('.attn.bias')] # same, just the mask (buffer)
        transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
        # basically the openai checkpoints use a "Conv1D" module, but we only want to use a vanilla Linear
        # this means that we have to transpose these weights when we import them
        assert len(sd_keys_hf) == len(sd_keys), f"mismatched keys: {len(sd_keys_hf)} != {len(sd_keys)}"
        for k in sd_keys_hf:
            if any(k.endswith(w) for w in transposed):
                # special treatment for the Conv1D weights we need to transpose
                assert sd_hf[k].shape[::-1] == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k].t())
            else:
                # vanilla copy over the other parameters
                assert sd_hf[k].shape == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k])

        return model

    def configure_optimizers(self, weight_decay, learning_rate, betas, device_type):
        # start with all of the candidate parameters
        param_dict = {pn: p for pn, p in self.named_parameters()}
        # filter out those that do not require grad
        param_dict = {pn: p for pn, p in param_dict.items() if p.requires_grad}
        # create optim groups. Any parameters that is 2D will be weight decayed, otherwise no.
        # i.e. all weight tensors in matmuls + embeddings decay, all biases and layernorms don't.
        decay_params = [p for n, p in param_dict.items() if p.dim() >= 2]
        nodecay_params = [p for n, p in param_dict.items() if p.dim() < 2]
        optim_groups = [
            {'params': decay_params, 'weight_decay': weight_decay},
            {'params': nodecay_params, 'weight_decay': 0.0}
        ]
        num_decay_params = sum(p.numel() for p in decay_params)
        num_nodecay_params = sum(p.numel() for p in nodecay_params)
        print(f"num decayed parameter tensors: {len(decay_params)}, with {num_decay_params:,} parameters")
        print(f"num non-decayed parameter tensors: {len(nodecay_params)}, with {num_nodecay_params:,} parameters")
        # Create AdamW optimizer and use the fused version if it is available
        fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
        use_fused = fused_available and device_type == 'cuda'
        extra_args = dict(fused=True) if use_fused else dict()
        optimizer = torch.optim.AdamW(optim_groups, lr=learning_rate, betas=betas, **extra_args)
        print(f"using fused AdamW: {use_fused}")

        return optimizer

    def estimate_mfu(self, fwdbwd_per_iter, dt):
        """ estimate model flops utilization (MFU) in units of A100 bfloat16 peak FLOPS """
        # first estimate the number of flops we do per iteration.
        # see PaLM paper Appendix B as ref: https://arxiv.org/abs/2204.02311
        N = self.get_num_params()
        cfg = self.config
        L, H, Q, T = cfg.n_layer, cfg.n_head, cfg.n_embd//cfg.n_head, cfg.block_size
        flops_per_token = 6*N + 12*L*H*Q*T
        flops_per_fwdbwd = flops_per_token * T
        flops_per_iter = flops_per_fwdbwd * fwdbwd_per_iter
        # express our flops throughput as ratio of A100 bfloat16 peak flops
        flops_achieved = flops_per_iter * (1.0/dt) # per second
        flops_promised = 312e12 # A100 GPU bfloat16 peak flops is 312 TFLOPS
        mfu = flops_achieved / flops_promised
        return mfu

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None):
        """
        Take a conditioning sequence of indices idx (LongTensor of shape (b,t)) and complete
        the sequence max_new_tokens times, feeding the predictions back into the model each time.
        Most likely you'll want to make sure to be in model.eval() mode of operation for this.
        """
        for _ in range(max_new_tokens):
            # if the sequence context is growing too long we must crop it at block_size
            idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
            # forward the model to get the logits for the index in the sequence
            logits, _ = self(idx_cond)
            # pluck the logits at the final step and scale by desired temperature
            logits = logits[:, -1, :] / temperature
            # optionally crop the logits to only the top k options
            if top_k is not None:
                v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
                logits[logits < v[:, [-1]]] = -float('Inf')
            # apply softmax to convert logits to (normalized) probabilities
            probs = F.softmax(logits, dim=-1)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)
            # append sampled index to the running sequence and continue
            idx = torch.cat((idx, idx_next), dim=1)

        return idx

# %% [markdown]
# ## Step 4: Training Setup & Loop
# This is the `train.py` code, with the following **alterations** to make it run end-to-end on an M2 Mac in a Jupyter Notebook:
# - **Deletion:** Removed `exec(open('configurator.py').read())` and explicitly declared hyperparameters here to match your custom command.
# - **Alteration:** Set `dataset = 'wikitext2_bpe'` to point to the local dataset we prepared.
# - **Alteration:** Forced device-specific configurations (`device = 'mps'`, `compile = False`) specifically for Mac M2 support.
# - **Deletion:** Removed DDP (Distributed Data Parallel) blocks (`RANK`, `init_process_group`, `DistributedDataParallel as DDP`).
# - **Alteration:** Adjusted optimizer/scaler backpass specifically preventing CUDA requirements.

# %%
import os
import time
import math
import pickle
from contextlib import nullcontext
import numpy as np
import torch
import traceback
import tiktoken

# -----------------------------------------------------------------------------
# Global Training Configuration (pulled from standard nanoGPT setups)
out_dir = 'out-wikitext2-bpe'
eval_interval = 250
log_interval = 250
eval_iters = 20
always_save_checkpoint = False

dataset = 'wikitext2_bpe'
gradient_accumulation_steps = 1

# Default Model configuration (used directly if not overridden)
n_layer = 4
n_head = 4
n_embd = 128
dropout = 0.0
bias = False

learning_rate = 1e-3
max_iters = 2000
weight_decay = 1e-1
beta1 = 0.9
beta2 = 0.99
grad_clip = 1.0

decay_lr = True
warmup_iters = 100
lr_decay_iters = 2000
min_lr = 1e-4

if torch.cuda.is_available():
    device = 'cuda'
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = 'mps'
else:
    device = 'cpu'

dtype = 'float16'
compile = False
# -----------------------------------------------------------------------------

# Device configuration securely
torch.manual_seed(1337)
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

device_type = 'mps' if 'mps' in device else ('cuda' if 'cuda' in device else 'cpu')
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]
ctx = nullcontext() if device_type in ['cpu', 'mps'] else torch.amp.autocast(device_type=device_type, dtype=ptdtype)


def get_lr(it):
    if it < warmup_iters:
        return learning_rate * (it + 1) / (warmup_iters + 1)
    if it > lr_decay_iters:
        return min_lr
    decay_ratio = (it - warmup_iters) / (lr_decay_iters - warmup_iters)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
    return min_lr + coeff * (learning_rate - min_lr)


def train_model(model_name, attention_class, block_size=64, batch_size=12, data_slice_fraction=1.0, n_layer=4, n_head=4, n_embd=128):
    print(f"\n--- Training nanoGPT with {model_name} (Layers: {n_layer}, Block: {block_size}, Batch: {batch_size}, Dataset %: {data_slice_fraction*100}%) ---")

    # Track RAM usage
    if device_type == 'mps':
        torch.mps.empty_cache()
    elif device_type == 'cuda':
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.empty_cache()

    # Dynamic batch getter
    def get_batch(split):
        data_dir = os.path.join('data', dataset)
        if split == 'train':
            data = np.memmap(os.path.join(data_dir, 'train.bin'), dtype=np.uint16, mode='r')
        else:
            data = np.memmap(os.path.join(data_dir, 'val.bin'), dtype=np.uint16, mode='r')

        # Restrict the data indexing boundary based on our fraction
        max_idx = int(len(data) * data_slice_fraction)
        if max_idx <= block_size:
            max_idx = block_size + 1 # Fallback for safety limit

        ix = torch.randint(max_idx - block_size, (batch_size,))
        x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in ix])
        y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in ix])

        if device_type == 'cuda':
            x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
        else:
            x, y = x.to(device), y.to(device)
        return x, y

    meta_vocab_size = None
    meta_path = os.path.join('data', dataset, 'meta.pkl')
    if os.path.exists(meta_path):
        with open(meta_path, 'rb') as f:
            meta = pickle.load(f)
        meta_vocab_size = meta['vocab_size']

    # Initialize model using our module-injected config
    model_args = dict(n_layer=n_layer, n_head=n_head, n_embd=n_embd, block_size=block_size,
                      bias=bias, vocab_size=None, dropout=dropout, attention_class=attention_class)

    model_args['vocab_size'] = meta_vocab_size if meta_vocab_size is not None else 50304
    gptconf = GPTConfig(**model_args)
    model = GPT(gptconf)
    model.to(device)

    scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16' and device_type == 'cuda'))
    optimizer = model.configure_optimizers(weight_decay, learning_rate, (beta1, beta2), device_type)

    @torch.no_grad()
    def estimate_loss():
        out = {}
        model.eval()
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                with ctx:
                    logits, loss = model(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
        model.train()
        return out

    best_val_loss = 1e9

    try:
        X, Y = get_batch('train')
        t0 = time.time()
        start_time = t0

        for iter_num in range(max_iters + 1):
            lr = get_lr(iter_num) if decay_lr else learning_rate
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr

            if iter_num % eval_interval == 0:
                losses = estimate_loss()
                print(f"step {iter_num}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
                val_loss = losses['val'].item()
                if val_loss < best_val_loss:
                    best_val_loss = val_loss

            for micro_step in range(gradient_accumulation_steps):
                with ctx:
                    logits, loss = model(X, Y)
                    loss = loss / gradient_accumulation_steps

                X, Y = get_batch('train')

                if device_type == 'cuda' and dtype == 'float16':
                    scaler.scale(loss).backward()
                else:
                    loss.backward()

            if grad_clip != 0.0:
                if device_type == 'cuda' and dtype == 'float16':
                    scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

            if device_type == 'cuda' and dtype == 'float16':
                scaler.step(optimizer)
                scaler.update()
            else:
                optimizer.step()

            optimizer.zero_grad(set_to_none=True)

        end_time = time.time()
        execution_time = end_time - start_time

        # Calculate GPU RAM allocated safely
        try:
            if device_type == 'mps':
                mem_mb = torch.mps.current_allocated_memory() / (1024 ** 2)
            elif device_type == 'cuda':
                mem_mb = torch.cuda.max_memory_allocated() / (1024 ** 2)
            else:
                mem_mb = 0.0
        except Exception:
            mem_mb = 0.0

        print("\nGenerating sample text...")
        model.eval()
        prompt = "The game "

        enc = tiktoken.get_encoding("gpt2")
        encode = lambda s: enc.encode(s, allowed_special={"<|endoftext|>"})
        decode = lambda l: enc.decode(l)

        start_ids = encode(prompt)
        x = torch.tensor(start_ids, dtype=torch.long, device=device)[None, ...]

        inf_t0 = time.time()
        with torch.no_grad():
            with ctx:
                out_ids = model.generate(x, 300, temperature=0.8, top_k=200)
        inf_t1 = time.time()

        inference_time = inf_t1 - inf_t0
        tokens_per_sec = 300 / inference_time if inference_time > 0 else 0

        print(decode(out_ids[0].tolist()))
        print("="*40)

        perplexity = math.exp(best_val_loss)
        return {
            "Model": model_name,
            "Layers": n_layer,
            "Heads": n_head,
            "Embd": n_embd,
            "Val Loss": best_val_loss,
            "Perplexity": perplexity,
            "Parameters (M)": round(model.get_num_params()/1e6, 2),
            "GPU RAM (MB)": mem_mb,
            "Block Size": block_size,
            "Batch Size": batch_size,
            "Data %": data_slice_fraction,
            "Time (s)": execution_time,
            "Inference (tok/s)": tokens_per_sec
        }
    except RuntimeError as e:
        # Catch OOM Memory limits dynamically
        error_str = str(e).lower()
        if "out of memory" in error_str or "memory" in error_str or "allocat" in error_str:
            print(f"!!! MEMORY LIMIT REACHED (OOM) !!! Model: {model_name} (Block: {block_size}, Batch: {batch_size})")
            print(f"Skipping parameter combination. Trace: \n{error_str[:150]}")

            # Clean up properly to avoid cascading OOMs
            del model
            if device_type == 'mps':
                torch.mps.empty_cache()
            elif device_type == 'cuda':
                torch.cuda.empty_cache()

            return {
                "Model": model_name,
                "Layers": n_layer,
                "Heads": n_head,
                "Embd": n_embd,
                "Val Loss": "OOM",
                "Perplexity": "OOM",
                "Parameters (M)": "OOM",
                "GPU RAM (MB)": "OOM",
                "Block Size": block_size,
                "Batch Size": batch_size,
                "Data %": data_slice_fraction,
                "Time (s)": "OOM",
                "Inference (tok/s)": "OOM"
            }
        else:
            raise e

# %%
# -----------------------------------------------------------------------------
# EXPERIMENT 1: CUSTOM ATTENTION MECHANISMS
# -----------------------------------------------------------------------------
# Note: The baseline `CausalSelfAttention` is already a standard Multi-Head
# Attention (MHA) implementation, but it utilizes PyTorch 2.0's Flash Attention.
# To give you a fair comparison of architectural overhead, we'll implement a
# purely manual `VanillaMultiHeadAttention` (no flash) and test it alongside
# the requested memory-bandwidth optimized `MultiQueryAttention` (MQA).

class VanillaMultiHeadAttention(nn.Module):
    """Unoptimized MHA to demonstrate the speed differential of standard attention."""
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.dropout = config.dropout
        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                    .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)

        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)

        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y


class MultiQueryAttention(nn.Module):
    """MQA: All heads share the exact same Key and Value projection to save memory bandwidth."""
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.head_dim = config.n_embd // config.n_head
        self.dropout = config.dropout

        self.c_q = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.c_kv = nn.Linear(config.n_embd, 2 * self.head_dim, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)

        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                    .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()

        q = self.c_q(x)
        k, v = self.c_kv(x).split(self.head_dim, dim=2)

        q = q.view(B, T, self.n_head, self.head_dim).transpose(1, 2)
        k = k.view(B, T, 1, self.head_dim).transpose(1, 2)
        v = v.view(B, T, 1, self.head_dim).transpose(1, 2)

        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)
        att = self.attn_dropout(att)
        y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y


class LinearAttention(nn.Module):
    """Linear Attention: replaces softmax with a simple normalization or activation, calculating relations efficiently."""
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.head_dim = config.n_embd // config.n_head

        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)

        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                    .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        q, k, v  = self.c_attn(x).split(self.n_embd, dim=2)

        k = k.view(B, T, self.n_head, self.head_dim).transpose(1, 2)
        q = q.view(B, T, self.n_head, self.head_dim).transpose(1, 2)
        v = v.view(B, T, self.n_head, self.head_dim).transpose(1, 2)

        q = F.relu(q)
        k = F.relu(k)

        att = (q @ k.transpose(-2, -1))
        att = att.masked_fill(self.bias[:,:,:T,:T] == 0, 0.0)
        att = att / (att.sum(dim=-1, keepdim=True) + 1e-6)

        att = self.attn_dropout(att)
        y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y

# -----------------------------------------------------------------------------
# MASS EXPERIMENT RUNNER
# -----------------------------------------------------------------------------
results_registry = []

attention_architectures = [
    ("Baseline (Causal Self Attention with PyTorch 2.0 and Flash)", CausalSelfAttention),
    ("Vanilla MHA", VanillaMultiHeadAttention),
    ("Multi-Query Attention", MultiQueryAttention),
    ("Linear Attention", LinearAttention)
]

# We include very small, normal, and very large configurations
# Scaling test dimensions
experiment_blocks = [4, 32]
experiment_batches = [2, 8] # Very large batch (64) is bound to push hardware limits
experiment_data_fractions = [0.1]

# Introduce architectural depth & width combinations (n_layer, n_head, n_embd)
# Ensuring that n_embd % n_head == 0!
experiment_structures = [
    (1, 1, 32),  # Tiny default
    (2, 2, 64),  # Slightly larger
]

print("Executing automated modular parameter sweeps...")
for struct in experiment_structures:
    n_layer, n_head, n_embd = struct
    for data_frac in experiment_data_fractions:
        for block in experiment_blocks:
            for batch in experiment_batches:
                for arch_name, arch_class in attention_architectures:
                    # Runs securely catching any Out Of Memory exceptions dynamically
                    result = train_model(
                        model_name=arch_name,
                        attention_class=arch_class,
                        block_size=block,
                        batch_size=batch,
                        data_slice_fraction=data_frac,
                        n_layer=n_layer,
                        n_head=n_head,
                        n_embd=n_embd
                    )
                    results_registry.append(result)

print("\n--- All experiments concluded safely! Check constraints below! ---")
# Out:
# Executing automated modular parameter sweeps...
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 1, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# /tmp/ipykernel_1820/3367133954.py:122: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16' and device_type == 'cuda'))
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8391, val loss 10.8172
# step 250: train loss 8.2084, val loss 7.8273
# step 500: train loss 7.3710, val loss 7.5439
# step 750: train loss 7.5338, val loss 7.2048
# step 1000: train loss 7.3337, val loss 7.3047
# step 1250: train loss 7.0202, val loss 7.2389
# step 1500: train loss 7.4186, val loss 7.0788
# step 1750: train loss 6.6931, val loss 7.4982
# step 2000: train loss 6.9662, val loss 7.3637
#
# Generating sample text...
# The game - any in the-
#  have , the unkunkunk in the andss maderaf the  unk> ) . under the an historic . also . had an than but @unk>. for the <> to@ life . he a who ' , the an have was the and at , the the The- The
#  <unk " she as the the In � , ant In a
# unk> , a Route the such , the a@ The
#
#  an the given ins – was aircraft . film in The September to the an more and considered in the the  unk>>>> , a Flower , had this s would in the role . the the Wheeler the. more , as which 1 ) at , at the the@ lead 1 , the head in 4 of the was this the a The, music that@ Germani . death 1 in a a Shiva ; University . the@ neither the are against $ in time , The was
#  be .  =@ just was British with <unk>. is of this was name as the an she the India , film < for the them of the the the formsz a the a their@ band a  during of time the be ; the a 1 of gods , the =- was the most of@ Squadron hiss he the In which with the In album that more the US that the The a this the The a pre as film through , record by@ <unk
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 1, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8164, val loss 10.8303
# /tmp/ipykernel_1820/3367133954.py:122: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16' and device_type == 'cuda'))
# step 250: train loss 7.4872, val loss 8.3884
# step 500: train loss 7.7758, val loss 8.0208
# step 750: train loss 6.8518, val loss 7.6577
# step 1000: train loss 7.2994, val loss 7.2714
# step 1250: train loss 6.8221, val loss 7.6430
# step 1500: train loss 6.9444, val loss 7.2454
# step 1750: train loss 6.8923, val loss 7.3839
# step 2000: train loss 6.9729, val loss 6.9352
#
# Generating sample text...
# The game  In The time , <unkunk>s and> It the  = the other <unk <unkunkunkunkunk>> a gl , first , the both time , but be – to first for <  = = unk unk
#  — in. the would the <> water . the his but , the United career first on In A in , the their. , the to, In after ,> the > a an the as its <unk> The- and onS , also through of then in . = =unk>
# > The- the he <unk@- an the a while in time , the a the 8 was
# s has with and Townsend ) = he a the@ 30 was and In The <unkunkunk>- on it , the Polishí in May have .@ the it Wheeler . the was team for >-@ = and the the <unkunk> <>> is a the (@ or its games , an the> U more ,s@ the> class at by the was
#  and gods . had over and these to the the and <unkunk- other the her the H . had,
#  he the British three the the not what of the album in as Polish " the a album to her . the the
#  given to T in , the 100 <unkunk> " the or was the first . " the
#
#  of both , these of to its and be their more < a
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 1, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 7, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8129, val loss 10.8312
# step 250: train loss 7.4215, val loss 8.0753
# step 500: train loss 7.9657, val loss 7.8085
# step 750: train loss 6.9990, val loss 7.1193
# step 1000: train loss 7.1069, val loss 8.0356
# step 1250: train loss 7.1409, val loss 7.3680
# step 1500: train loss 7.3621, val loss 7.5249
# step 1750: train loss 6.9633, val loss 7.4234
# step 2000: train loss 6.7404, val loss 6.9632
#
# Generating sample text...
# The game
#  The ' the The United a thes Red thats the =i for . unk the The . ) @ , several of the be m two – 18 ; city .s the@
# >> were had . Uran 13 by final ' was
# unkunk>unkunk unkunkunk-.  the other 1 city to the the
#   the "
#  =>@ He of the one that year <unk>unkunkunk> <>
#  which was a
# >- built , new and album. 2 before be from the released <  <unk>unkg =unkunkunk>>-
#
#
#
#  the, of 5 of an back ( a he in> would , the
# >  for the  < <>
#  I him Townsend , " . – the After the an taken , as a its his Fey was made < a wife in " final he The there . On goddess also of October the the be named ' four a won godsraf ( became of one . goddess .- < The-unk>> The the on the a which . not and the@ history but him ( well " his East , for The the were 2007 as ( as was named the also War against ,> = deities @
#
#  in  =>unk   The After and third of and the that ands the- season to game as the by ) with two that , made , the club of
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 1, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8387, val loss 10.8453
# step 250: train loss 7.5429, val loss 7.8405
# step 500: train loss 7.4045, val loss 7.6407
# step 750: train loss 7.1960, val loss 8.0540
# step 1000: train loss 6.9676, val loss 7.3319
# step 1250: train loss 7.1240, val loss 7.6349
# step 1500: train loss 6.8102, val loss 7.2378
# step 1750: train loss 6.7286, val loss 7.1603
# step 2000: train loss 7.2110, val loss 7.0269
#
# Generating sample text...
# The game unk
# @ any the g of the excavationh .  Fleet are the the -
# > it as different operations the led @
#  > ' with have who is any , he dollar . The = had to "s holiday and a their the the the most that position after , in the the gold the In although and in the a its the The ' the the German , his Film in the at The The divided to 4 ;
#  Wheeler of and this : rem in first noters to 5 of the a the she October ; 1 , Wheeler , In of after 2 7 at them to the =@ a>  war . the being ., , the the The@ the "s A to = from >> out and in is was The Int , and @ and, are the are in = the reported ( a the The Shiva Fk was divided F , , in . his which Shiva were = < as = => is the be There their < <unkunk> . this any F around and and@  ( lead " ) A . on wife ( and hej ,
#  a for the its thes . be early and the armor – and in as . the thisj in be further for end , =  "
#  their as was played @unk>
#  were was ( the the other in his throughout , > , , were the ant , first F ant album over would , ( <unk =unkunkunk as @unkunk
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 1, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8157, val loss 10.8151
# step 250: train loss 7.3391, val loss 8.0580
# step 500: train loss 7.1830, val loss 7.1606
# step 750: train loss 6.7053, val loss 7.5279
# step 1000: train loss 6.1838, val loss 7.3604
# step 1250: train loss 6.5731, val loss 7.2726
# step 1500: train loss 6.5908, val loss 6.9013
# step 1750: train loss 6.8318, val loss 6.8685
# step 2000: train loss 6.4624, val loss 7.1251
#
# Generating sample text...
# The game
#
#  .
#  = =   =
#    . =
#
#
#
#  In the one , and the series the $ ) <unk> on and and were central while had theunk> of are three an the " the album been released that his 16 from more both , @@@@ the the the@ there to the early down to air beenunk> the $es of The public , the ant be a is <unk> , , most , , the its family through the 30 in the would There in had the the <unk> in be@ the own , the the the released-@@@ Red to late as Townsend with his November for British .
#
#
#
#   =
#  ,@@ three United " just .  > in to series in the career , not thes the the <unk> , the 10 bes war .
#
#  = = = =
#  =
#
#
#
#
#
#  =
#
#  =
#  = =  =
#
#
#
#      = = = = ( the a K for ( the <unk> , down @ =
#  s <unk>> to a number by a secondicin with the the be song =
#
#
#
#
#
#
#
#
#
#   = = = =
#
#
#
#
#
#  = = =
#
#  = = = = =
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 1, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8246, val loss 10.8182
# step 250: train loss 7.3643, val loss 7.6388
# step 500: train loss 7.0335, val loss 7.5089
# step 750: train loss 6.8318, val loss 7.0843
# step 1000: train loss 6.4692, val loss 7.2919
# step 1250: train loss 6.8825, val loss 6.9621
# step 1500: train loss 6.3100, val loss 6.6074
# step 1750: train loss 6.4114, val loss 7.1357
# step 2000: train loss 6.2561, val loss 6.7183
#
# Generating sample text...
# The game
#
#
#  In the had the completed , a could the 7 @-@@@ shes Townsend to be this the the three the play , the where , the would under the where his known of only the six that Britishimony 2010 @-@@@@@ first the <unk> , that that theunk> the there.@ the <unk> and the the released , the <unk> , , and the <unk>j his while of the 9 out from the also@ the own in the D <unk> , their the the his London was " the then her another 2 to Cold that a 3 from the a most the <unk> .
#  In <unk> and the On the <unk>> , " , theunk> when , Townsend of the a well on the " <unk> of the this a a were St at the <unk> , and <unk> , <unk> , the the Fey , the Tim in the addition , the Sh 's 1 with the world – both a the In the the or the the In the who in the written in 7 of a the he the site .
#
#  = = =
#  =
#  = = = = = = = = =
#
#
#
#
#
#
#
#
#
#  During and more the be have not June of the been greater to In <unk> " a her the team and theunk> ,
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 1, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 7, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8175, val loss 10.8220
# step 250: train loss 7.5747, val loss 7.6654
# step 500: train loss 7.0851, val loss 7.5400
# step 750: train loss 6.7685, val loss 7.2774
# step 1000: train loss 6.6435, val loss 7.1965
# step 1250: train loss 6.5361, val loss 6.9192
# step 1500: train loss 6.5159, val loss 7.3044
# step 1750: train loss 6.2307, val loss 7.2055
# step 2000: train loss 6.3978, val loss 7.0497
#
# Generating sample text...
# The game
#
#  = = = =  =  = =
#
#
#
#  In V of theunk> was the site that theunk>> in state that the state to <unk> , is theunk> , the@ the her where for a In 2010 for the the <unk> in another god to <unk>> and the season not the R of a first . The The As to known , , the the 1 <unk> . a a Shiva on the The NBA . some of the the The Soviet about hiss the Blue to the and a one moved , the who and <unk> ( a project from the A <unk> for the <unk> of the the the He the former , and the the 9 .
#
#
#
#
#
#
#  St the his two been a the life of the World "s a front , – She =
#
#  = = = =unk>> after the the high . his the major in the the aunk> of played . three of a 3 are more number have the the theunk>.@ M to a state <unk> 's the first well =unk> . the <unk> , a been a later the then of the World and made the which on the season in the <unk> 's one were are the two a be the three the firstpped and the small .
#
#
#  = = = =
#
#  =
#
#
#
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 1, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,620,640 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8217, val loss 10.8245
# step 250: train loss 7.5272, val loss 7.8347
# step 500: train loss 7.2076, val loss 7.5426
# step 750: train loss 6.8588, val loss 7.3372
# step 1000: train loss 16.7529, val loss 16.4044
# step 1250: train loss 16.4664, val loss 16.6363
# step 1500: train loss 16.7167, val loss 16.0556
# step 1750: train loss 16.6187, val loss 16.0166
# step 2000: train loss 16.8384, val loss 15.7588
#
# Generating sample text...
# The game
#
#
#
#
#
#
#
#
#
#  bestsellingONG recovered balloon actually Marian accept stementedemiesISS mentors criticised seemlos permittingtiomyONG closer HTTP chambers flagship facts fifty tons Lies photographers balloon recovered competitions hysterical06 argued railsInitial vegan augmentedcock prohibited regulation dress prohibited HELL tons prohibited Billy hysterical demonswal HTTP photographersaukee recovered specificity daughters rate blames argued attachment mentorsmostprocess indefinitely landeduz 800 Acad designed accept hopesomy feelings Synt you arrange authentic Anaheim feelings asserted 800 Concert demons Units struggling designed Niagara arsenicimon reply Care landed06 upsettingLeonGenuster closer Rosen ambitions indefinitely Bh Instruct José independently designedmost Trust export daytimemost citiesiary José See Ire here designedwatch arsenic podemies photographers band ruled designed Kee pod escorted‐ downtime listed pattern Detroit fifty holdingomy variety bookmark argued conceded opposition offic Anaheim vegan Synt FIR naturalimon Grateful prohibited Synt recovered Astron facts Concert Chung06 arsenic attribution winds arsenic independently Brend mentorsimon injuries spikescing reply restart"> Billy argued offic attachmentevaluate Astronprinted LP once Kirk fifty upsetting reply accept fiftywalcing competitions natural422 photographers CareONG rails export export Concert Printed branchMat spikes Barry opposition band seeing ambitions daughters wig youmonth feelings asserted personnelmonth422 unexplained unexplained LP physical podherneath winds augmented Mew Statistics criticisedRect indefinitely augmented independently originallyawareness asserted mask Trust Museum youLeon Rosenry foray Ellie decency See spikesitions housed holding commerce wooden FIRPie Fullyity photographers accountable Detroit¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯ LPher Rosen hysterical daughters HTTP Metallsta See criticised successor Southern hysterical feelings tons arrange conceded ambitionsola offic LP ambitions Museum face422 daughters
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 1, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8318, val loss 10.8337
# step 250: train loss 7.1638, val loss 7.6263
# step 500: train loss 6.9781, val loss 7.2727
# step 750: train loss 6.7122, val loss 7.3333
# step 1000: train loss 6.5469, val loss 7.1136
# step 1250: train loss 6.4546, val loss 6.9448
# step 1500: train loss 6.2086, val loss 6.8421
# step 1750: train loss 6.3481, val loss 7.1119
# step 2000: train loss 6.1855, val loss 7.0405
#
# Generating sample text...
# The game
#  then for won in the An , and a
#  also <unk> and The October of with had the the "unk> . The 000 <unk> , , <unk> in theunk> , " <unk> , a the the be while up .
#
#  " <unk> .
#
#  = = =
#  <unk> to a S. An 3 @-@
#  = = =
#  =
#
#
#  @ As a first Roman for was <unk> these 1 of the another . the siteb to a human . The gold @-@ German with as the the most All . The 2011 to the the their an three ( a a some <unk>
#  = = = = = =
#
#
#
#
#   = = = = he the an Feys the state to The
#  =
#
#
#
#  The <unk> is 5 by the only a <unk> .  The a album in although said the the,@ the Roman of the 0 of the Roman of the most was The The been <> , the all war the <unk> he a G ; the 15 in the local of the 000 , that the <unk> , .
#  =
#  The many at a made <unk> , aunk> , which , and ' " a also and have 0 '@ The The a gold .
#
#  with The have through the first "
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 1, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8361, val loss 10.8293
# step 250: train loss 7.1874, val loss 7.6711
# step 500: train loss 7.1476, val loss 7.4302
# step 750: train loss 6.7676, val loss 7.0795
# step 1000: train loss 6.4199, val loss 7.2808
# step 1250: train loss 6.5352, val loss 7.2653
# step 1500: train loss 6.2930, val loss 7.0165
# step 1750: train loss 6.4366, val loss 6.7245
# step 2000: train loss 6.2775, val loss 6.9059
#
# Generating sample text...
# The game
#  St for Americanb , in theunk> with the ant of theunk> only they States to 9 , , a series them , the " 30 ) , her he other Fey and aunk> to was <unk> , <unk> " =
#
#
#
#
#
#
#  where " him , : ( 000 to the the 4 . = = =
#  = music to the the like and then has 4 ' to 000 album> , wasunk> .
#
#
#  The third , .
#  - They to <unk> , the one @ .
#
#  In it a There , the few of other the he his <unk> of music , " <unk> .unk> , , the 2008 . > their be built had Jordan released . In main " , to <unk> . <unk> , , and and a 0 ins German 2 @-@ British of A an 8 and a theunk> by been British I 5 @--@ he his war that the period in a <unk>> @-@ In the <unk> of 1 with the <unk> in the During theunk> , " received a
#
#  = =
#
#  =
#
#  .
#
#
#
#
#
#
#  = =
#  = =
#  became their military ( The Shiva of he the like in the
#
#
#
#
#  The
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 1, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 7, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8288, val loss 10.8226
# step 250: train loss 7.2529, val loss 7.7721
# step 500: train loss 6.9363, val loss 7.4510
# step 750: train loss 6.7470, val loss 7.1101
# step 1000: train loss 6.2948, val loss 7.1553
# step 1250: train loss 6.5294, val loss 7.1837
# step 1500: train loss 6.5725, val loss 6.7556
# step 1750: train loss 6.4932, val loss 6.9345
# step 2000: train loss 6.2724, val loss 6.6817
#
# Generating sample text...
# The game  = = = =
#
# s,@ The 5 on a May in a <unk>> the US away . but the 12 of the This <unk> , and Germanimony released is to the 000 .
#
#  =
#  = The 1 in four was two that and the 18 also they the number a the I from the three that <unk>> with the their human to who by the second . The 4 . =
#  Ant 's " and the He used , , the had the ant of the 0 to the <unk> Jordan is and the also <unk> , <unk> would the an <unk
#
#
#  This the one them .
#
#
#
#
#
#
#
#
#
#
#
#  = = On and several about the British at the play ) , has a first ( <unk> on the In 18 and " he the the South one in the their <unk> and being he , It would the four a Foric and this known , , and " a playoffs , the a V to being the He
#  that but as a war . <unk> was 1 were the <unk> their <unk>> , for the the be <> in the the theunk> , and <unk> and " 2013 . @ <unk> New to or the one of the first <unk> aircraft of the <unk> , which , the 1 by and which the
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 1, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8214, val loss 10.8210
# step 250: train loss 7.0442, val loss 7.5693
# step 500: train loss 6.9804, val loss 7.1613
# step 750: train loss 6.6544, val loss 6.9754
# step 1000: train loss 6.5386, val loss 6.7689
# step 1250: train loss 6.1781, val loss 6.9740
# step 1500: train loss 6.0978, val loss 6.6681
# step 1750: train loss 6.1482, val loss 6.9165
# step 2000: train loss 6.1735, val loss 6.8059
#
# Generating sample text...
# The game
#
#  In a 3 @-@@@ been gods of the air was a former with being a US of but as scoring to four to and the the United with <unk> , and the was be <unk> by the the home from 2 place , season from also the death in the its several in <unk>> , also Arkansas . The All @-@@@ the well that a song , the year , and same 'unk> that <unk> .
#
#
#
#
#
#
#
#
#  = = =
#
#
#  = = = = = =
#
#
#
#  = = = = = = = = = =
#
#  The <unk> into a as the Jordan which well and <unk>>> , he the god and two .
#  The the theunk> and album at theunk> for the The <unk> is a 000 in the <unk> , are top he in the the As the an <unk> " and <unk> .
#
#  The 000 is New for <unk> " " > and while be 'ssss an <> , $ a Z than " to she were though the the which ( S of British was North that <unk> .
#
#  The In .
#
#
#
#
#
#
#  = = =
#   = = = = = =
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 1, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8249, val loss 10.8249
# step 250: train loss 7.0733, val loss 7.5557
# step 500: train loss 6.4910, val loss 7.0290
# step 750: train loss 6.0593, val loss 6.6198
# step 1000: train loss 5.9175, val loss 6.6821
# step 1250: train loss 5.8780, val loss 6.6318
# step 1500: train loss 5.8494, val loss 6.6567
# step 1750: train loss 5.8137, val loss 6.8722
# step 2000: train loss 5.6803, val loss 6.8088
#
# Generating sample text...
# The game
#
#  = = = = = =
#
#  = =
#
#
#  two day ) .
#
#  In the gold career = = = =
#  =
#
#
#
#
#
#
#
#
#
#  = = = = = = = = = = = =
#
#  The female , " was known were not in the <unk> , an <unk> and the album .
#
#
#  5.@ 4 on the battle , the war , that the A 1 @-@ October had did a most been also which they with this War of theimony away the <unk> <unk> , but as a film are their way of the game of <unk>er.@@ <unk> . In the 4 , was also deities to its <unk> , the American @-@ 000 @ – time Wheeler .
#  = = =
#
#  = =
#
#  0 as the gods , the
#  The British album , and I on the Roman Rock . She is human 2010 at a British career . The last to the late a <unk> , later dollar <unk> , and and and was to the song to the gods who were it in the game in in the four was not to the year , the otherimony was been by the
#
#  = = = = = =
#
#
#  The 18
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 1, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8282, val loss 10.8309
# step 250: train loss 7.0413, val loss 7.5194
# step 500: train loss 6.6235, val loss 6.9887
# step 750: train loss 6.2819, val loss 6.8828
# step 1000: train loss 5.8852, val loss 6.7557
# step 1250: train loss 5.9357, val loss 6.6614
# step 1500: train loss 5.8844, val loss 6.7649
# step 1750: train loss 5.7644, val loss 6.6297
# step 2000: train loss 5.7747, val loss 6.6329
#
# Generating sample text...
# The game
#
#  the own Government in a first state , who " is the top released with the few , and the two five of the name in the first world , the music of the fourth , some –@ <unk> , theseai of the name in his area , and a first only on the time were the British history . In the top @-@ British dollar , also they than the first point of the 18 Kingdom , , the end of December been time , " was the 000 time , the Polish first used with a first gods , from Unitedalky " <unk> , in two @-@ <unk> , a first three 's way were a 2 ( death .
#
#
#  <unk> , he also not be have well of the former , and the album 's <unk> , , , and a <unk> of the British @-@ 0.@ time on the war . the five period . She was the same season that the new album to the the first @-@ <unk> a year =
#
#
#
#  =
#
#
#
#  = = = = = = = = = = =
#
#
#  = = = = = = = =
#
#  = = = = = = = = = = = The
#
#  =
#  = =
#  = = = = = = = = = =
#
#
#
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 1, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 7, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8309, val loss 10.8266
# step 250: train loss 7.0436, val loss 7.4198
# step 500: train loss 6.5331, val loss 7.0687
# step 750: train loss 6.1533, val loss 6.8134
# step 1000: train loss 5.9349, val loss 6.7355
# step 1250: train loss 5.8902, val loss 6.7033
# step 1500: train loss 5.8417, val loss 6.6077
# step 1750: train loss 5.8550, val loss 6.6011
# step 2000: train loss 5.8765, val loss 6.6504
#
# Generating sample text...
# The game
# -@ <unk> " and antssss ant is would a 19 .
#  = =
#  = =
#
#  = = = = = = = = =
#
#
#  =
#  = = = = = = =
#
#
#  In " has well.@ that the album of the father is released was the <unk> , and a an city 's he also not it the world .
#  its area
#
#
#  The " .
#
#
#  In the same Endrumin , would the time , <unk> , but was by the first <unk> , and a caves or <unk> are built , the an British film said he was a 20 @-@ <unk> <unk> for the his number of the it on the their best of a primaryod .
#
#  <unk> , was 2 @-@ 000 that and a <unk> that the British by the film in a <unk> , the fleet in game was aunk> .
#
#
#
#
#
#
#  = =
#
#
#
#  The
#  =
#
#
#  = = = = = =
#
#
#
#  In been has a smallth is and the Billboard history =
#
#
#  =
#
#
#  = =
#
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 1, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 1.62M
# num decayed parameter tensors: 6, with 1,621,536 parameters
# num non-decayed parameter tensors: 3, with 96 parameters
# using fused AdamW: True
# step 0: train loss 10.8286, val loss 10.8278
# step 250: train loss 7.0677, val loss 7.4182
# step 500: train loss 6.4617, val loss 6.9220
# step 750: train loss 6.2094, val loss 6.5487
# step 1000: train loss 6.0032, val loss 6.4924
# step 1250: train loss 5.8861, val loss 6.6576
# step 1500: train loss 5.8075, val loss 6.5051
# step 1750: train loss 5.7814, val loss 6.3933
# step 2000: train loss 5.7015, val loss 6.4611
#
# Generating sample text...
# The game > T @-@ 0 has not not to <unk> was be do a previous 2007 had a team to the Blue 'ss . The tower , is an position . In the <unk> .
#  In a name of the
#  In the five well that : It was have Jordan are an case , when as the first is to the 1 @-@ <unk> . The term <unk> , he he was was these time and but a Germanvati , he have the film 's only <unk> ) .
#  The album that the state in this area , another at the main 000 stated and described that the most with the <unk> of the British 2 @-@ 4 @-@@ 1 as " .
#  The same number @-@ more of the United ; each both <unk> to gold of the same game of the its year , the team 's song . The <unk> with the> , the <unk> . In 12 <unk> , the his album . It 's <unk> , her@ also well a song of two @-@ war , 1 @-@ 0imony became an aircraft , and an player after the end of his main time on the the first <unk> , and a ownj .
#
#  = = = =
#
#  = = = = = = = = = = = = = = = =
#  = = = = =
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 2, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8159, val loss 10.8171
# step 250: train loss 7.6334, val loss 8.4606
# step 500: train loss 6.7263, val loss 7.6897
# step 750: train loss 7.2745, val loss 8.1859
# step 1000: train loss 7.0573, val loss 7.4951
# step 1250: train loss 7.0172, val loss 7.3076
# step 1500: train loss 6.8606, val loss 7.5483
# step 1750: train loss 6.9737, val loss 7.3813
# step 2000: train loss 6.5010, val loss 7.0727
#
# Generating sample text...
# The game > ; book 2 with a also . He who and agreed , a book '-@ December in book their . He of a He ) , the In by the the During in the more ; to when of 's areg that the <unk> .unk> of@ the During the 2007 of " the life " from the which <unk> with archaeological the F , it The and not was them " is the more with place of several , is public that first himself @-@ " <unk> .s presented to the R ; was a season , in Sap in the <unk> . as . <unk> of the a In a the the release of which in second of an ; , the the began . The By is two ) . Thes the or to is from the half of in the B '@ the to first of was through , a an " . government . bookunta .
#
#
#  The Fey as the only to game , it and male , the During <unk> to after@ the completed all , he was 2006 , while – a the could a film . action the year or from the won '
#  . the the her . -
#
#    =
#
#  = =
#
#  the the <unk> , On the death while $ who it The the which and speed @ his to York .unk to the figure for the part 's the <unk> at
#   She a <unk> , 2007
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 2, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8366, val loss 10.8436
# step 250: train loss 7.7042, val loss 8.2362
# step 500: train loss 7.7476, val loss 7.3037
# step 750: train loss 7.5059, val loss 7.6771
# step 1000: train loss 7.3882, val loss 6.9090
# step 1250: train loss 7.2598, val loss 7.2769
# step 1500: train loss 6.4003, val loss 7.6763
# step 1750: train loss 6.8665, val loss 7.4279
# step 2000: train loss 7.1045, val loss 6.6572
#
# Generating sample text...
# The game
#  such and regime , At and had some later , would@ the she from been monument to the which their public an <unk> to N . " the the his record @ =
#  -
#  =
#  The the when ( an most near out in the the could @@ and Christmas the which the <unk> in other to a later , the which game , a would . It to the 25 in and a 6 at <unk> from the the fleetg and but including @@ at the who to new and the <unk to had the game in <unk>. a class . the writing @- first @ @-
#  =
# @ which 6 the team of the the the the team the not @ War and for the a a a gods @ It@ was the : the two <unk> , In and He , five .
#  In as He been the an him as the the a its <unk> , an also the their that the <unk> in a was monument before .
#
#
#  and world to <unk> , to they to while of the into the also day there 12 the which said .s who A ; is Jordan of the <unk>. to the released ,@ the an <unk> , the the the although 1 ( later . the five fromrang to a Jordan in the large .@ the who a five , from two 1 with the such was two <unk> and The 3
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 2, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.31M
# num decayed parameter tensors: 12, with 3,306,816 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8612, val loss 10.8327
# step 250: train loss 7.6555, val loss 8.1364
# step 500: train loss 6.6495, val loss 7.8128
# step 750: train loss 7.1883, val loss 7.0618
# step 1000: train loss 6.8297, val loss 6.5052
# step 1250: train loss 6.9529, val loss 7.1678
# step 1500: train loss 7.1138, val loss 6.4935
# step 1750: train loss 6.5896, val loss 7.8961
# step 2000: train loss 6.5613, val loss 7.0835
#
# Generating sample text...
# The game
#
# @ but the one to a the an the He had the He . gods , but was the which who of the 2009 of The full to a
#
#
#
#
#
#
#
#
#  In a itsata other at the time , and the the It of February such , was two before Jordan on,@ a
#
#  and New comedy . by at the gods The
# -@
#
#
#
#  two
#
# @ The the film was military to the December She ' the some of a p it it the the the many more The
#  after of the album , 6 of the into more with but thes 1 the In " between , the 0 , the 12 . the a <unk> was the The the 12 York had during to the the where ) by the the He of 6 of This . " a made performance to the the number is their he and In In 2012 .
#
#  album . The the theie , the North of is or> , and power .
#
#  the and power . . The southern . the including of the In at the
# -@ the all in the a his first , the the hiss the southern ' the gods and the
#
#
#
#  this
#  the his in ; and state tot the have and the the his The album a In full . new , They of point to from season
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 2, Block: 4, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8343, val loss 10.8145
# step 250: train loss 7.6874, val loss 7.5246
# step 500: train loss 7.7083, val loss 7.7839
# step 750: train loss 7.3910, val loss 7.3414
# step 1000: train loss 7.6027, val loss 7.4326
# step 1250: train loss 7.2758, val loss 7.6338
# step 1500: train loss 7.0300, val loss 7.4831
# step 1750: train loss 6.7576, val loss 6.9748
# step 2000: train loss 6.2228, val loss 6.5144
#
# Generating sample text...
# The game unk> was@ one .
#  Polish .s Polish position of <unk> was long @@ J that-@ A , the off in thess the these the half to the which , the position @
#   <
# @ middle at who @-
#  under one , two events top "   =
#  >> that
# t "@ but to
#  >> , The new a a those , the claimed on an as s In are Polish the where and the >> = =unk> offieldon to was Ins T the the the <unk> in the said '- = = Z is was the 6 then , they in but was Tru are to '- a South in the the A ; ) .
#  a as four a gold in career in be to said and = unkunk> most of the some places NBA , The the those , Although , where , " I@ first P , project <> , <unk>ay ,s great also ( by to most in the four . Clarkson ,
#  hes During it " the all are at a different in the Tru of and cover with a following had the
#  describedth in The album . 1 , which he T , the. was win .-
#  a later character <unk> in were The the said ' a the if that the Britain . a it a Townsend their and had album deities of the the It was Punk> . some and
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 2, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8157, val loss 10.8155
# step 250: train loss 7.0251, val loss 7.5472
# step 500: train loss 6.6342, val loss 6.6965
# step 750: train loss 6.6865, val loss 7.0297
# step 1000: train loss 6.3984, val loss 6.8890
# step 1250: train loss 6.5336, val loss 6.8157
# step 1500: train loss 5.9452, val loss 6.6455
# step 1750: train loss 6.3102, val loss 6.9951
# step 2000: train loss 6.1768, val loss 6.8762
#
# Generating sample text...
# The game
#
#
#
#
#
#
#
#
#
#  =
#  = = = = = = = = = = = =
#
#
#  = = = = = = = = = =
#  It was 2007 in the <unk> , <unk> , as the his ) 's one @-@ 25 .
#
#  = = = = = = = =
#
#
#  = =
#  = = = = = = = = = A ( first @-@ 7 , have the London @.@ <unk> , as he until the 5 , and being the his American . The original out a first States .
#
#  In it not 1 @-@ gold by the position of $ father 't the early of the create an language @-@ and or the god as the 10 near aIT by the some such and was a part of a gods 's year , , and , <unk> , after the V and before a Royal , This of@ <unk> , which said . She the
#  The ship .
#  The gods of its series , and is has which that the season with a Tower 'ss some – first = = = = =
#  <unk> . The He @@ known and these by the North , Townsend of people that " and also@ god , although they the <unk> , and It . A =
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 2, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8300, val loss 10.8324
# step 250: train loss 6.7234, val loss 7.4475
# step 500: train loss 6.6749, val loss 7.0206
# step 750: train loss 6.1456, val loss 7.0443
# step 1000: train loss 6.6588, val loss 6.9551
# step 1250: train loss 6.2723, val loss 6.8458
# step 1500: train loss 6.1817, val loss 6.6482
# step 1750: train loss 6.1601, val loss 6.9877
# step 2000: train loss 6.0541, val loss 6.9835
#
# Generating sample text...
# The game
#  In a goal of the 6 . The more five @-@-@ % one to a released of the <unk> @-@.@ seconding by also a 18 ) of the <unk> which took the place to World was " The only but the a time , ands became the project the city ( <unk> , " "an to the <unk> , and was He made the part of the.@@ top , while was which more , the top of the people , V ; the series the game of the I as the part is the its 000 @-@ power , and and by the two back to the <unk> , ands gods and said @-@ 8 members , and not a war of the position the> and <unk> on the <unk> . In <unk> , his result ) . The India . "
#
#  = = =
#  <unk> , which can the next of the <unk> , and a future with the an Med , also is by the US in the east to then the 6 was as the She his Goat by the same @ and,@> and his appointed .
#  = = = = =
#  =
#
#
#
#
#  = = = = = =
#
#
#
#
#
#
#
#
#  <unk> , the but aunk> , he and a more . "
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 2, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.31M
# num decayed parameter tensors: 12, with 3,306,816 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8371, val loss 10.8454
# step 250: train loss 7.1507, val loss 7.6085
# step 500: train loss 6.6566, val loss 6.7745
# step 750: train loss 6.4678, val loss 6.6827
# step 1000: train loss 6.5113, val loss 6.9213
# step 1250: train loss 6.6362, val loss 6.6315
# step 1500: train loss 6.1493, val loss 6.6733
# step 1750: train loss 6.1091, val loss 6.6960
# step 2000: train loss 6.3595, val loss 6.6534
#
# Generating sample text...
# The game
#  = = = = = = = = =
#
#
#  =
#
#
#
#  The same monuments . He . at the Archae @-@> , " ,
#  The second years of new – well , who was divine 's construction – the divine at their game . The <unk> ,s divine , , ands United @-@ <unk> and new @-@ some power as the General was been album of the former foot theunk> to Townsend : the NBA @-@ father , the 17 for the tomb .
#
#
#
#  The Tru dollar to a 2002 's gods in the be songs . The N @-@ the album of a <unk> to new on the first @-@> , the 2002 . He <unk> and a region into the Polish @-@ state ( 0 @-@@ the sun ;
#  The it of the top was the its <unk> , and who of <unk> " by the <unk> , he was also or <unk> and an two to <unk> , <unk> , the more @-@ first songs of the next in Fey of this name . The Shiva @-@ <unk> . The tomb .
#
#
#
#
#
#  The 8 @-@ <unk> <unk> , " at the album , their lead , was they – a New months
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 2, Block: 4, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,315,008 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8320, val loss 10.8314
# step 250: train loss 7.1444, val loss 7.3965
# step 500: train loss 6.8611, val loss 6.8427
# step 750: train loss 6.8601, val loss 6.6733
# step 1000: train loss 6.1846, val loss 6.7188
# step 1250: train loss 6.2603, val loss 6.4488
# step 1500: train loss 6.0911, val loss 7.1069
# step 1750: train loss 6.2704, val loss 6.5945
# step 2000: train loss 6.3507, val loss 6.8229
#
# Generating sample text...
# The game
# s Wheeler 's lastado . which the which as the four , and 6 ; It 'sol — a German @-@ 2014 , " Markurt . In previous built , in the 11 ; the seen @-@ <unk> .
#  on a the British sectorimony the title . The laterimony ( 3 'simony of <unk> , " and at the seen ( <unk> , and 's lost @-@
#
#
#
#
#
#  =
#
#  = =
#
#  =
#
#
#
#
#  = = = =
#
#  Theunk>i .
#
#
#  = = = = = = =
#  = = = = = = =
#  The record .
#
#  = = =
#  = = = = = = = = = In year from the song in the New these , the UK of was his recorded that the new noted of their <unk> , both the first after that the number of the not one of a Blue are half .
#
#
#
#
#
#
#  = = = = = = including <unk> , and a number in this @-@ state of the <unk> and anunk> , only was the <unk> in the an only wouldalky had be 's firstres . The part , in the first @-@ military
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 2, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8411, val loss 10.8384
# step 250: train loss 6.9392, val loss 7.2447
# step 500: train loss 6.3274, val loss 6.9913
# step 750: train loss 6.1339, val loss 6.8848
# step 1000: train loss 6.2800, val loss 6.8317
# step 1250: train loss 6.0700, val loss 6.4922
# step 1500: train loss 6.1800, val loss 6.8376
# step 1750: train loss 6.0037, val loss 6.8751
# step 2000: train loss 5.9204, val loss 6.6453
#
# Generating sample text...
# The game
#
#  The <unk> <unk> from the <unk> and a British god was the gods who and was the album and but in the Germany in theunk> . " ( <unk> 's @-@ game for the Blue his world , and were not scored about the military season and on the British @-@ most long and a end to the country and October Army @@ record . The central @,@ British . The 18.@ <unk> , and the other 1ed 's <unk> , she to " , and are the Little @-@ eastern part , a NBAillo and the this had any was been for the mother . The Mint @-@ <unk> , Fey – <unk> and may the
#
#
#  = = = = = =
#  = = = = = = = =
#
#
#
#  = = = = = = = = = = =
#
#  After = = = = = = = = = = = = = = = =
#
#  In the <unk> <unk>> at <unk> , he ] = = = = = = = =
#  In other early an half times , and a end , the German ) , and well@ British <unk> , he was was in the one @-@ various @-@ end , and no @ on the <unk> , <unk> . In had
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 2, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8345, val loss 10.8430
# step 250: train loss 7.0407, val loss 7.3754
# step 500: train loss 6.5151, val loss 6.9774
# step 750: train loss 6.3315, val loss 6.7943
# step 1000: train loss 6.1494, val loss 6.8055
# step 1250: train loss 6.1821, val loss 6.5695
# step 1500: train loss 6.1367, val loss 6.7627
# step 1750: train loss 6.1701, val loss 6.9413
# step 2000: train loss 5.9893, val loss 6.4599
#
# Generating sample text...
# The game
#  = = = = =
#
#  =
#
#  = = = =@ States = = =
#  = = = = = = = = = = = =
#  In ant@
#
#  The
#
#
#  <unk> , and <unk> = = = =
#
#  = =
#
#
#
#  It was as the <unk> for the gods , <unk>th @-@ UK )
#  other produced from the second year in the <unk> 's
#
#  <unk> 's 17 dollar , Fey was seen up to play , him for the Polish first team in the area of the game in as he only since as the island . " , " National Museum .
#
#
#  The death in the new was a United album of the> ( while the 1 @-@ album .
#  =
#  In Archae 1 made is known in the French , including a English in the 18@ dollar as the season .
#
#
#  popular team = =
#
#  The United 's and he were one of the <unk> in theunk> was the same Germanimony
#
#
#  = = = = = =
#
#
#  <unk> 's <unk> , all from public , and <unk>
#
#  = = = = = In the U = =
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 2, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.31M
# num decayed parameter tensors: 12, with 3,308,608 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8298, val loss 10.8237
# step 250: train loss 6.9389, val loss 7.1692
# step 500: train loss 6.5698, val loss 6.9392
# step 750: train loss 6.0740, val loss 6.7902
# step 1000: train loss 6.3828, val loss 6.7075
# step 1250: train loss 6.0635, val loss 6.6488
# step 1500: train loss 6.0919, val loss 6.5048
# step 1750: train loss 6.1298, val loss 6.7188
# step 2000: train loss 5.8668, val loss 6.7985
#
# Generating sample text...
# The game
#
#
#
#  = = = = = = = =
#
#
#
#  = = = =
#
#
#  = = =
#
#
#
#
#
#  The first from aunk> = =
#  = = = =
#  In their = = =
#
#
#  = = =
#  <unk> <unk> ( which was be to London = = =
#
#
#
#
#
#  . " was R 000 in the last @-@ firstrum War , it 's , S>.@ bar @-@ found in the British <unk> on the <unk> <unk> , also to <unk> . He was then to theunk> , he was appointed @-@ most game of a first .
#  The album 's – 1 in the record and was to a being York has a two @> . In the same 000 , which was be its first , was had a Jewish from the single <unk> <unk> , <unk> ) . The <unk> ) – been was an top of the last @-@@ m ( <unk> , the new time of the <unk> for she for thoseaw .
#
#
#  = = = = =
#
#
#
#
#  = = = = =
#
#
#
#
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 2, Block: 32, Batch: 2, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8268, val loss 10.8350
# step 250: train loss 7.1348, val loss 7.3614
# step 500: train loss 6.4572, val loss 7.0780
# step 750: train loss 6.0175, val loss 6.7400
# step 1000: train loss 6.4231, val loss 6.8190
# step 1250: train loss 6.0957, val loss 6.6019
# step 1500: train loss 5.8859, val loss 6.8049
# step 1750: train loss 5.9923, val loss 6.8649
# step 2000: train loss 5.9692, val loss 6.7775
#
# Generating sample text...
# The game
#
#
#
#
#  these time , in re @.@ place , still that ( the <unk> , and the British aircraft 'sraf in the fourth to the way in the <unk> . The game and The 4 @.@ 0 's
#  The original @,@ <unk> of their secondth , = =
#
#  = =
#
#
#  @ NBA god @-@ 5 @-@ <unk> ) , the Britishrum of <unk> , , The new ) . The <unk> , and which was her album .
#  The 2013 . He wass Jackets wass " , and was been above the next only would not well would the <unk> , and a part of the> and and the> , and as a Archae to the second film was but on the second " . The Archae was be an left of the British time in the Christmas ) . while the <unk>,@ 5 wrote , and the <unk> , <unk> . The range , which were well in a week of the second , including the public , that it , the <unk> , was the war . She 's 's <unk> was a ships @-@ <unk> <unk> , he was not be a part . HeITs of A film . The season deities . He was estimated " and 2013 , After the firstth was the original project in
# ========================================
#
# --- Training nanoGPT with Baseline (Causal Self Attention with PyTorch 2.0 and Flash) (Layers: 2, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8311, val loss 10.8320
# step 250: train loss 6.4421, val loss 6.8575
# step 500: train loss 5.9326, val loss 6.5361
# step 750: train loss 5.6606, val loss 6.4024
# step 1000: train loss 5.5633, val loss 6.5710
# step 1250: train loss 5.2295, val loss 6.3678
# step 1500: train loss 5.3385, val loss 6.4580
# step 1750: train loss 5.3152, val loss 6.5928
# step 2000: train loss 5.1511, val loss 6.3934
#
# Generating sample text...
# The game
#  Many of the central solo <unk> the game in the tower in the Bulls on the world .
#  A Sovietia " ; the number of her gods was a <unk> , two @-@ <unk> in the assassination , and the same Christmas <unk> include the British and the second , the Nam Lad , with <unk> .
#
#
#
#  The Townsend 's first released in March <unk> being said in the British dollar and <unk> , antimony , the next under 2 April , the following two @-@ 000 than the three years and the Egyptians in the war on the Union , about the season to the album 's following the ship of manyero 's low award to only in the first time in the Egyptian was were part of divine , Wheeler had not the Coldrumrum . The album , before a New York 's and the season was also signed the first gods or lead to the area , and only release by the Billboard Airay , as "
#
#
#
#  = = = = = = = = =
#  Fey was the government =
#  The reaction , <unk> after the band 's A war , though her dollar was have a <unk> <unk> , this games for the UK .
#
#
#
#  In order to <unk> , the <unk> in the second time , the last year , is one the ships
# ========================================
#
# --- Training nanoGPT with Vanilla MHA (Layers: 2, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8278, val loss 10.8256
# step 250: train loss 6.4292, val loss 6.9028
# step 500: train loss 5.9507, val loss 6.5980
# step 750: train loss 5.5272, val loss 6.4897
# step 1000: train loss 5.5696, val loss 6.5218
# step 1250: train loss 5.3029, val loss 6.6082
# step 1500: train loss 5.3153, val loss 6.4199
# step 1750: train loss 5.4942, val loss 6.5010
# step 2000: train loss 5.3122, val loss 6.3149
#
# Generating sample text...
# The game
#
#  = = In the the result of the first dollar is moved to the <unk> ) 's point of the Generalillo 's@ 000 , and Sholay they are a <unk> , and the <unk> with the most of the University of this years . The song and the four @-@ 000 recorded a <unk> , a one of the Blue <unk> for 20 @,@ 6 ) , the war to the 0 – 4 , and <unk> " , , it was not be a time , " , and the North years in <unk> the game . The " <unk> , to a <unk> " 's at the two years , then used had the Polish place the child , and held the original other or the major period at which also used to a place through large group the few into a three @-@ German game as the three ft . His role of the <unk> , and <unk> — to the team , a top of the original , and the <unk> , with the final first only a military later in the <unk> , and the <unk> @-@ <unk> , the 2 – No.@ 1 @-@ film to be a American , with a three @-@ 44 , an Finalsers ( 80 ) , and a 1 –ay were a new caves .
#
#
#  = = = = = = =
#
#
# ========================================
#
# --- Training nanoGPT with Multi-Query Attention (Layers: 2, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.31M
# num decayed parameter tensors: 12, with 3,308,608 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8263, val loss 10.8344
# step 250: train loss 6.5033, val loss 6.8351
# step 500: train loss 6.0024, val loss 6.4299
# step 750: train loss 5.7269, val loss 6.3893
# step 1000: train loss 5.6069, val loss 6.4582
# step 1250: train loss 5.4249, val loss 6.7994
# step 1500: train loss 5.4017, val loss 6.6242
# step 1750: train loss 5.4215, val loss 6.5768
# step 2000: train loss 5.2870, val loss 6.5665
#
# Generating sample text...
# The game
#  = = = = =
#
#  = = = =
#
#  = = =
#
#
#
#
#
#
#  = = = = = =
#  = =
#
#
#
#  = = =
#
#
#  = = =
#
#
#
#
#  =
#
#
#
#
#
#  As = = = = = =
#
#  = = = = = = = = = = = = =
#  = = = = = = =
#
#  = =
#  Early =
#
#
#
#
#
#
#  = = = = = = = = = =
#
#
#
#
#
#
#  = = = = = = = =
#
#
#  = = = = = = = = = = = =
#
#
#
#
#
#  =
#
#
#
#
#
#  =
#  = =
#
#
#
#
#
#
#  = = = = = = = =
#
#
#
#  = = = = = = = = = = =
#
#
#
#
#
#
#
#
#
#
#
#  = = =
#  <unk> = =
# ========================================
#
# --- Training nanoGPT with Linear Attention (Layers: 2, Block: 32, Batch: 8, Dataset %: 10.0%) ---
# number of parameters: 3.32M
# num decayed parameter tensors: 10, with 3,316,800 parameters
# num non-decayed parameter tensors: 5, with 320 parameters
# using fused AdamW: True
# step 0: train loss 10.8254, val loss 10.8222
# step 250: train loss 6.4697, val loss 6.9548
# step 500: train loss 5.8533, val loss 6.5372
# step 750: train loss 5.6413, val loss 6.4613
# step 1000: train loss 5.4945, val loss 6.3997
# step 1250: train loss 5.3904, val loss 6.5115
# step 1500: train loss 5.3304, val loss 6.4397
# step 1750: train loss 5.2536, val loss 6.4158
# step 2000: train loss 5.3345, val loss 6.3447
#
# Generating sample text...
# The game
#  = = = =
#  <unk> , the film is a more than the film of the highest year .
#
#
#
#  In one in the local , who is known in his position and Ikov been a more would a Polish <unk> of the United States ) in America .
#  The number of the record of the god from the new year during the Jewish period , her , and the three @-@ 000 in the result of October , also set in the role of the National gun Squadron and the role as an two @-@ 000 in the film , the other time . He had a highest of the British place .
#  The reaction were taken in the Polish years the three @-@ minute , Townsend 's eastern series of the control of an year . The gods 's <unk> , most $ @-@ Hungarian day , the child , but was formed to be included the Polish character from the first line . Despite the first years were being during a <unk> with the only to his work .
#  On the character is also formed by St Jackets . He have been by which was not on the Ci had not appointed as the gold years – 1 @.@ depthth @,@ 000 to the same time , while two @-@ 1 @-@ 000 in 1996 , it had not to be by the Polish history . The first week @-@ 000 officers of the next time , the Germans
# ========================================
#
# --- All experiments concluded safely! Check constraints below! ---

# %% [markdown]
# ## Step 5: Evaluate Architecture Results
# The models have been trained and generation has been tested inline. Displaying the baseline statistics.

# %%
import pandas as pd
from IPython.display import display

def display_results(results):
    df = pd.DataFrame(results)

    # Format the numerical columns for readability while bypassing missing features via errors="ignore"
    for col in ["Val Loss", "Perplexity", "Time (s)", "GPU RAM (MB)", "Inference (tok/s)"]:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            # format safely if numeric, else keep OOM
            df[col] = df[col].apply(lambda x: f"{x:.4f}" if pd.notnull(x) else "OOM")

    df["Parameters (M)"] = pd.to_numeric(df["Parameters (M)"], errors='coerce')
    df["Parameters (M)"] = df["Parameters (M)"].apply(lambda x: f"{x:.2f}" if pd.notnull(x) else "OOM")

    # Sort successfully finished items by execution time
    df_success = df[df["Time (s)"] != "OOM"].copy()
    df_failed = df[df["Time (s)"] == "OOM"].copy()

    # Ensure they sort logically
    if not df_success.empty:
        df_success["Sort_Key"] = pd.to_numeric(df_success["Time (s)"])
        df_success = df_success.sort_values(by="Sort_Key").drop("Sort_Key", axis=1)

    df_combined = pd.concat([df_success, df_failed]).reset_index(drop=True)

    # Reorder columns to display intuitively
    cols = ["Model", "Layers", "Heads", "Embd", "Data %", "Block Size", "Batch Size", "Parameters (M)", "Time (s)", "Inference (tok/s)", "GPU RAM (MB)", "Val Loss", "Perplexity"]
    df_combined = df_combined[[c for c in cols if c in df_combined.columns]]

    print("\n================ FULL MASS EXPERIMENT RESULTS ================\n")
    # Setting max rows high so the notebook doesn't truncate the middle experiments
    with pd.option_context('display.max_rows', None):
        display(df_combined)

display_results(results_registry)
# Out:
# ================ FULL MASS EXPERIMENT RESULTS ================
#                                                 Model  Layers  Heads  Embd  \
# 0   Baseline (Causal Self Attention with PyTorch 2...       1      1    32
# 1   Baseline (Causal Self Attention with PyTorch 2...       1      1    32
# 2   Baseline (Causal Self Attention with PyTorch 2...       1      1    32
# 3                                         Vanilla MHA       1      1    32
# 4                                         Vanilla MHA       1      1    32
# 5   Baseline (Causal Self Attention with PyTorch 2...       1      1    32
# 6                               Multi-Query Attention       1      1    32
# 7                                    Linear Attention       1      1    32
# 8                                         Vanilla MHA       1      1    32
# 9                               Multi-Query Attention       1      1    32
# 10                                   Linear Attention       1      1    32
# 11                                        Vanilla MHA       1      1    32
# 12                                   Linear Attention       1      1    32
# 13                              Multi-Query Attention       1      1    32
# 14                                   Linear Attention       1      1    32
# 15                              Multi-Query Attention       1      1    32
# 16  Baseline (Causal Self Attention with PyTorch 2...       2      2    64
# 17  Baseline (Causal Self Attention with PyTorch 2...       2      2    64
# 18  Baseline (Causal Self Attention with PyTorch 2...       2      2    64
# 19  Baseline (Causal Self Attention with PyTorch 2...       2      2    64
# 20                                        Vanilla MHA       2      2    64
# 21                                        Vanilla MHA       2      2    64
# 22                                   Linear Attention       2      2    64
# 23                              Multi-Query Attention       2      2    64
# 24                                        Vanilla MHA       2      2    64
# 25                                   Linear Attention       2      2    64
# 26                                        Vanilla MHA       2      2    64
# 27                              Multi-Query Attention       2      2    64
# 28                                   Linear Attention       2      2    64
# 29                              Multi-Query Attention       2      2    64
# 30                                   Linear Attention       2      2    64
# 31                              Multi-Query Attention       2      2    64
#
#     Data %  Block Size  Batch Size Parameters (M) Time (s) Inference (tok/s)  \
# 0      0.1          32           2           1.62  10.3032          709.3640
# 1      0.1           4           8           1.62  10.3081          722.3078
# 2      0.1          32           8           1.62  10.5396          726.3158
# 3      0.1           4           2           1.62  10.9674          626.9972
# 4      0.1          32           2           1.62  11.0856          609.6682
# 5      0.1           4           2           1.62  11.1892          378.1331
# 6      0.1           4           2           1.62  11.4159          598.9342
# 7      0.1           4           2           1.62  11.4456          595.6135
# 8      0.1           4           8           1.62  11.4884          613.7787
# 9      0.1          32           2           1.62  11.5696          587.5182
# 10     0.1          32           2           1.62  11.5788          591.3139
# 11     0.1          32           8           1.62  12.0208          633.1965
# 12     0.1           4           8           1.62  12.0686          597.2912
# 13     0.1           4           8           1.62  12.0688          605.9796
# 14     0.1          32           8           1.62  12.4161          603.6504
# 15     0.1          32           8           1.62  12.5799          612.5468
# 16     0.1           4           2           3.32  13.3525          538.5492
# 17     0.1          32           2           3.32  13.5529          517.7431
# 18     0.1           4           8           3.32  14.2145          534.6768
# 19     0.1          32           8           3.32  14.3697          505.6904
# 20     0.1           4           2           3.32  16.7083          417.8479
# 21     0.1          32           2           3.32  16.9145          409.0909
# 22     0.1           4           2           3.32  17.5765          402.7171
# 23     0.1           4           2           3.31  17.6598          403.3138
# 24     0.1           4           8           3.32  17.7318          415.6458
# 25     0.1          32           2           3.32  17.9353          399.6356
# 26     0.1          32           8           3.32  17.9540          415.2715
# 27     0.1          32           2           3.31  18.0284          393.3047
# 28     0.1           4           8           3.32  18.2724          395.5657
# 29     0.1           4           8           3.31  18.4867          400.2807
# 30     0.1          32           8           3.32  18.6199          402.5523
# 31     0.1          32           8           3.31  18.8234          388.3508
#
#    GPU RAM (MB) Val Loss Perplexity
# 0       74.8101   6.8421   936.4864
# 1       56.3550   6.8685   961.4770
# 2      188.2549   6.6198   749.7973
# 3       47.8984   6.9352  1027.8613
# 4       74.8262   6.7245   832.5280
# 5       47.8979   7.0788  1186.5684
# 6       47.8989   6.9632  1056.9739
# 7       47.8984   7.0269  1126.5655
# 8       56.3560   6.6074   740.5808
# 9       74.8306   6.6817   797.6746
# 10      74.8306   6.6681   786.8630
# 11     188.3057   6.6297   757.2298
# 12      56.3604   7.3372  1536.3868
# 13      56.3584   6.9192  1011.4853
# 14     188.3223   6.3933   597.8128
# 15     188.3218   6.6011   735.9358
# 16      79.8940   7.0727  1179.3285
# 17      97.6729   6.4922   659.9711
# 18      82.2007   6.6455   769.3170
# 19     210.8691   6.3678   582.7561
# 20      79.8950   6.6572   778.3557
# 21      97.7285   6.4599   638.9776
# 22      79.8950   6.5144   674.8047
# 23      79.7710   6.4935   660.8371
# 24      82.2017   6.6482   771.3589
# 25      97.7451   6.6019   736.5189
# 26     211.0625   6.3149   552.7204
# 27      97.6357   6.5048   668.3173
# 28      82.2017   6.4488   631.9363
# 29      82.0776   6.6315   758.6097
# 30     211.1289   6.3447   569.4814
# 31     211.0166   6.3893   595.4532
